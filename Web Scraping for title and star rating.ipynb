# %% [markdown]
# <a href="https://colab.research.google.com/github/danishmohib/Web_Scraping/blob/main/Web%20Scraping%20for%20title%20and%20star%20rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
books=[]
for i in range(1,51):
  url='https://books.toscrape.com/'
  response=requests.get(url)
  response=response.content
  soup=BeautifulSoup(response,'html.parser')
  soup
  ol=soup.find('ol')
  articles=ol.find_all('article',class_='product_pod')
  articles

  for article in articles:
    image=article.find('img')
    title=image.attrs['alt']
    print(title)
    star=article.find('p')
    star=star['class']
    print(star)

    price=article.find('p',class_='price_color').text
    price=float(price[1:])
    books.append([title,price,star])
df=pd.DataFrame(books, columns=['Title','Price','Star Rating'])
df.to_csv('books.csv')
# Out:
# A Light in the Attic
# ['star-rating', 'Three']
# Tipping the Velvet
# ['star-rating', 'One']
# Soumission
# ['star-rating', 'One']
# Sharp Objects
# ['star-rating', 'Four']
# Sapiens: A Brief History of Humankind
# ['star-rating', 'Five']
# The Requiem Red
# ['star-rating', 'One']
# The Dirty Little Secrets of Getting Your Dream Job
# ['star-rating', 'Four']
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# ['star-rating', 'Three']
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# ['star-rating', 'Four']
# The Black Maria
# ['star-rating', 'One']
# Starving Hearts (Triangular Trade Trilogy, #1)
# ['star-rating', 'Two']
# Shakespeare's Sonnets
# ['star-rating', 'Four']
# Set Me Free
# ['star-rating', 'Five']
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# ['star-rating', 'Five']
# Rip it Up and Start Again
# ['star-rating', 'Five']
# ...

# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r"C:\Users\HP\Desktop\Power BI Data\Titanic.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-f430d40bf4bf> in <cell line: 4>()
#       2 import numpy as np
#       3
# ----> 4 df=pd.read_csv(r"C:\Users\HP\Desktop\Power BI Data\Titanic.csv")
#       5 print(df)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
